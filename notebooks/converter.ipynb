# %%
import json
import pandas

# %%
def cross_join(left, right):
    return left.assign(key=1).merge(right.assign(key=1), on='key', how='outer').drop('key', 1)

def json_to_dataframe(data_in):
    def to_frame(data, prev_key=None):
        if isinstance(data, dict):
            df = pandas.DataFrame()
            for key in data:
                df = cross_join(df, to_frame(data[key], prev_key + '.' + key))
        elif isinstance(data, list):
            df = pandas.DataFrame()
            for i in range(len(data)):
                df = pandas.concat([df, to_frame(data[i], prev_key)])
        else:
            df = pandas.DataFrame({prev_key[1:]: [data]})
        return df
    return to_frame(data_in)

# %%
def normalize_json(data: dict):
  
    new_data = dict()
    for key, value in data.items():
        if not isinstance(value, dict):
            new_data[key] = value
        else:
            for k, v in value.items():
                new_data[key + "_" + k] = v
  
    return new_data
  
  
def generate_csv_data(data: dict):
  
    # Defining CSV columns in a list to maintain
    # the order
    csv_columns = data.keys()
  
    # Generate the first row of CSV 
    csv_data = ",".join(csv_columns) + "\n"
  
    # Generate the single record present
    new_row = list()
    for col in csv_columns:
        new_row.append(str(data[col]))
  
    # Concatenate the record with the column information 
    # in CSV format
    csv_data += ",".join(new_row) + "\n"
  
    return csv_data

# %%
with open('../data/song_dataV6.json', 'r', encoding='utf-8') as json_file:
    json_data = json.load(json_file)

# %%
import pandas as pd

# %%
df = pd.read_json('../data/song_dataV6.json')

# %%
df.head()
# Out:
#    id                        title                     topic  \
# 0   1    Aadaraya sundara varadaki                 love life
# 1   2     Aadaraye ulpatha wu amma                motherhood
# 2   3  Aalen wela ganna kolam kala  staring or blooming love
# 3   4            Ada dee geka giya      broken love & sorrow
# 4   5               Adara mal wala  staring or blooming love
#
#                                    Lyrics in english  \
# 0  Aadaraya sundara varadaki\nkisidaa samaavak na...
# 1  Aadaraye ulpatha wu amma\nMaa obage puthu wu……...
# 2  Aalen wela ganna kolam kala\nHitha aalen muda ...
# 3  Ada dee geka giya nuba mata Bulath athak deela...
# 4  Adara mal wala… pata kiyannada\nEwage lassana…...
#
#                                    Lyrics in sinhala  \
# 0  ආදරය සුන්දර වරදකි\nකිසිදා සමාවක්‌ නම් නැති\nමට...
# 1  ආදරයේ උල්පත වූ අම්මා\nමා ඔබගේ පුතු වූ..\nඔබ මත...
# 2  ආලෙන් වෙලා ගන්න කෝලම් කලා\nහිත ආලෙන් මුදා ගන්න...
# 3  අද දීගෙක ගිය නුඹ මට බුලත් අතක් දීලා\nයන්න පිටත...
# 4  ආදර මල් වල පාට කියන්නද\nමේ වගෙ ලස්සන තව නෑ\nමේ...
#
#                                     Singer              Music  \
# 0                    Karunarathna Diwlgane    Gunadasa Kapuge
# 1                        Victor Rathnayake  Victor Rathnayake
# 2  Athula Adikari With Samitha Mudunkotuwa   Madawa Hewawasam
# 3                        Sunil Edirisinghe   Madawa Hewawasam
# 4                            Kasun Kalhara  Nawarathna Gamage
#
#                      Lyrics                                         Annotation
# 0      Yamuna Malini Perera  [{'Line': 6, 'Metaphore': 'nuvan daaley', 'Obj...
# 1     Premakeerthi De Alwis  [{'Line': 2, 'Metaphore': 'Aadaraye ulpatha wu...
# 2          Madawa Hewawasam  [{'Line': 2, 'Metaphore': 'aadare bhawanawak w...
# 3          Madawa Hewawasam  [{'Line': 4, 'Metaphore': 'Nethe kandulu sirak...
# 4  Wasantha Kumara Kobawaka  [{'Line': 2, 'Metaphore': 'mal sitha', 'Object...

# %%
df.to_csv('../data/data.csv', index=False)

# %%
df1 = df.copy()

# %%
df1.set_index('id', inplace=True)

# %%
anns = df1['Annotation']

# %%
anns.items()

# %%
annotation_data = []
for i, v in anns.items():
    # print(i, v, type(v))
    for a in v:
        a['Song ID'] = i 
        annotation_data.append(a)

# %%
df2 = pd.DataFrame().from_records(annotation_data)
df2.head()
# Out:
#    Line                 Metaphore       Object-sinhala  Object-english  \
# 0     6              nuvan daaley                nuvan             eye
# 1     2  adaraya sundara varadaki              adaraya            love
# 2    14                hada svara                 hada           heart
# 3    12             veenaa bandin                veena           harps
# 4     2  Aadaraye ulpatha wu amma  Aadaraye ulpatha wu  source of love
#
#     Subject-sinhala Subject-english  Song ID
# 0          induwara             sun        1
# 1  sundara varadaki         mistake        1
# 2             svara           notes        1
# 3            bandin             hip        1
# 4              amma          mother        2

# %%
df.iloc[:, :-1].to_csv('../data/song_data.csv', index=False, encoding='utf-8')

# %%
df2.to_csv('../data/annotation_data.csv', index=False)

# %%
ss_df = pd.read_csv('../data/song_data.csv')
ss_df.head()
# Out:
#    id                        title                     topic  \
# 0   1    Aadaraya sundara varadaki                 love life
# 1   2     Aadaraye ulpatha wu amma                motherhood
# 2   3  Aalen wela ganna kolam kala  staring or blooming love
# 3   4            Ada dee geka giya      broken love & sorrow
# 4   5               Adara mal wala  staring or blooming love
#
#                                    Lyrics in english  \
# 0  Aadaraya sundara varadaki\nkisidaa samaavak na...
# 1  Aadaraye ulpatha wu amma\nMaa obage puthu wu……...
# 2  Aalen wela ganna kolam kala\nHitha aalen muda ...
# 3  Ada dee geka giya nuba mata Bulath athak deela...
# 4  Adara mal wala… pata kiyannada\nEwage lassana…...
#
#                                    Lyrics in sinhala  \
# 0  ආදරය සුන්දර වරදකි\nකිසිදා සමාවක්‌ නම් නැති\nමට...
# 1  ආදරයේ උල්පත වූ අම්මා\nමා ඔබගේ පුතු වූ..\nඔබ මත...
# 2  ආලෙන් වෙලා ගන්න කෝලම් කලා\nහිත ආලෙන් මුදා ගන්න...
# 3  අද දීගෙක ගිය නුඹ මට බුලත් අතක් දීලා\nයන්න පිටත...
# 4  ආදර මල් වල පාට කියන්නද\nමේ වගෙ ලස්සන තව නෑ\nමේ...
#
#                                     Singer              Music  \
# 0                    Karunarathna Diwlgane    Gunadasa Kapuge
# 1                        Victor Rathnayake  Victor Rathnayake
# 2  Athula Adikari With Samitha Mudunkotuwa   Madawa Hewawasam
# 3                        Sunil Edirisinghe   Madawa Hewawasam
# 4                            Kasun Kalhara  Nawarathna Gamage
#
#                      Lyrics
# 0      Yamuna Malini Perera
# 1     Premakeerthi De Alwis
# 2          Madawa Hewawasam
# 3          Madawa Hewawasam
# 4  Wasantha Kumara Kobawaka
